# %%
from lazypredict.Supervised import LazyClassifier, LazyRegressor
from sklearn.model_selection import train_test_split
import pandas as pd

# %% [markdown]
# # converting categorical features to object datatypes

# %%
l = ['HomePlanet_Europa', 'HomePlanet_Mars', 'Destination_PSO J318.5-22','Destination_TRAPPIST-1e','CryoSleep_True', 'VIP_True', 
     'Expense_encoded', 'Deck_fact',	'Cabin_side_fact']
for i in l:
    x_train[i] = data[i].astype(object)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4300/2016788670.py in <module>
#       2      'Expense_encoded', 'Deck_fact',	'Cabin_side_fact']
#       3 for i in l:
# ----> 4     x_train[i] = data[i].astype(object)
#
# NameError: name 'data' is not defined

# %%
X = data.iloc[:,2:]
Y = data.iloc[:,1:2]

# %%
X
# Out:
#      HomePlanet_Europa HomePlanet_Mars Destination_PSO J318.5-22  \
# 0                    1               0                         0
# 1                    0               0                         0
# 2                    1               0                         0
# 3                    1               0                         0
# 4                    0               0                         0
# ...                ...             ...                       ...
# 8688                 1               0                         0
# 8689                 0               0                         1
# 8690                 0               0                         0
# 8691                 1               0                         0
# 8692                 1               0                         0
#
#      Destination_TRAPPIST-1e CryoSleep_True VIP_True  Expense_scaled  \
# 0                          1              0        0           -0.73
# ...

# %% [markdown]
# # Training without any feature selection

# %%
train_x, test_x,train_y, test_y = train_test_split(X,Y, shuffle = True)

# %%
train_x
# Out:
#      HomePlanet_Europa HomePlanet_Mars Destination_PSO J318.5-22  \
# 7117                 1               0                         0
# 7200                 1               0                         0
# 3057                 0               1                         0
# 3828                 0               1                         0
# 5511                 0               0                         0
# ...                ...             ...                       ...
# 507                  0               0                         0
# 8536                 0               0                         1
# 7153                 1               0                         0
# 6235                 0               0                         0
# 869                  0               0                         0
#
#      Destination_TRAPPIST-1e CryoSleep_True VIP_True  Expense_scaled  \
# 7117                       0              1        0           -0.73
# ...

# %%
y_train
# Out:
#       Unnamed: 0  Transported
# 0              0            0
# 1              1            1
# 2              2            0
# 3              3            0
# 4              4            1
# ...          ...          ...
# 8688        8688            0
# 8689        8689            0
# 8690        8690            1
# 8691        8691            0
# 8692        8692            1
#
# [8693 rows x 2 columns]

# %%
x_train = pd.read_csv(r'x_train.csv')
x_test = pd.read_csv(r'x_test.csv')
y_train= pd.read_csv(r'y_train.csv')

# %%
x_train = x_train.iloc[:, 1:]
y_train = y_train.iloc[:, 1:]

# %%
train_x, test_x,train_y, test_y = train_test_split(x_train,y_train, shuffle = True)

# %%
train_x
# Out:
#       HomePlanet_Mars  Destination_PSO J318.5-22  Destination_TRAPPIST-1e  \
# 4531                1                          0                        1
# 3147                0                          1                        0
# 7592                0                          0                        0
# 7793                1                          0                        0
# 5069                1                          0                        1
# ...               ...                        ...                      ...
# 4869                0                          0                        0
# 8684                1                          0                        1
# 5612                1                          0                        1
# 6794                0                          0                        1
# 143                 0                          0                        1
#
#       CryoSleep_True  VIP_True  Expense_scaled  Expense_encoded  Age_scaled  \
# ...

# %%
clf = LazyClassifier(predictions=True)

models, predictions = clf.fit(train_x, test_x,train_y, test_y)
# Out:
#  90%|████████▉ | 26/29 [00:34<00:05,  1.69s/it]
# [19:45:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 100%|██████████| 29/29 [00:36<00:00,  1.25s/it]

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.75               0.75     0.75      0.75
# BaggingClassifier                  0.74               0.74     0.74      0.74
# RandomForestClassifier             0.74               0.74     0.74      0.74
# NuSVC                              0.73               0.73     0.73      0.73
# AdaBoostClassifier                 0.73               0.73     0.73      0.73
# XGBClassifier                      0.73               0.73     0.73      0.73
# ExtraTreesClassifier               0.73               0.73     0.73      0.73
# LinearDiscriminantAnalysis         0.73               0.73     0.73      0.73
# RidgeClassifierCV                  0.73               0.73     0.73      0.73
# RidgeClassifier                    0.73               0.73     0.73      0.73
# LinearSVC                          0.73               0.73     0.73      0.73
# ...
